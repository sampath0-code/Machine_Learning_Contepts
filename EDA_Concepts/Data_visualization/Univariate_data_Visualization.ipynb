# %% [markdown]
# # DATA VISUALIZATION TECHINUQUES
#
#    Data visualization makes things easier to understand and helps us to communicate the information easily.
#
#      Here we are using the iris dataset for the use cases

# %% [markdown]
# ## Classifications

# %% [markdown]
# 1. As per the number of variables chosen, the data variables are classified as Univariate, Bivariate and multivariate.
# 2. Ex : If we want to visualize on only one varible then it is a Univariate data. For Bivariate it's and and for multivariate it is multiple.
# 3. And further based on the characteristics of data, it can be classified as categorical/discrete and continuous data.

# %% [markdown]
# ## Univariate data
# ### In this module we will discuss about the Visualization on Univariate data
# They are two types
# 1. Uni-variate continues data
# 2. Uni-veriate catagorical data
#
#
#
# Pandas stores categorical variables as ‘object’ and, on the other hand, continuous variables are stored as int or float. The methods used for visualization of univariate data also depends on the types of data variables.

# %% [markdown]
# Importing the libraries matplot lib and sea born
#
# 1.   We use Matplotlib library to draw basic plots. Seaborn library is based on the matplotlib library and it provides a wide variety of visualization techniques for univariate data.

# %% [markdown]
#   importing libraries
#    pandas, numpy, matplotlib.pyplot and seaborn

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading iris dataset useing pd.read_csv()

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/iris.csv')

# %% [markdown]
# The data set originally in .csv format is loaded into the DataFrame df using the pd.read_csv( ) function of pandas . Then, it displays the DataFrame df.

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.info()

# %% [markdown]
# # Uni-variate continues data :
# Univariate data visualization plots help us comprehend the enumerative properties as well as a descriptive summary of the particular data variable.
#
# These plots help in understanding the location or position of observations in the data variable, its distribution, and dispersion
#
# They are two types :
# 1. Enumerative plots
# 2. Summary plots

# %% [markdown]
# # **Enumerative plots**
# These plots enumerate or show every observation in data and provide information about the distribution of the observations on a single data variable.

# %% [markdown]
# # 1. Univariate Scatter Plot :
#   This plots different observations or values of the same variable corresponding to the index or observation number. Consider plotting of the variable :

# %%
plt.scatter(df.index, df['sepal.width'])

# %% [markdown]
# Now visualize the same plot by considering its 'variety' varible using the seaborn library.
#
# youtube link of scatter plot
# https://www.youtube.com/watch?v=4yz4cMXCkuw

# %%
sns.scatterplot(x = df.index, y = df['sepal.width'], hue = df['variety'])

# %% [markdown]
# # 2. Univariate Line plot :
# A line plot visualizes data by connecting the data points via line segments. It is similar to a scatter plot except that the measurement points are ordered (typically by their x-axis value) and joined with straight line segments.
# Though there is no such automated option available in matplotlib, one can use the groupby() function of pandas which helps in plotting such a graph.
#
# for more details
# https://www.youtube.com/watch?v=CMRVEKf9jWA&list=PLtPIclEQf-3cG31dxSMZ8KTcDG7zYng1j&index=10

# %%
plt.figure(figsize = (6,6))
plt.title('Line plot of petal length')
plt.xlabel('index',fontsize = 20)
plt.ylabel('petal lenght',fontsize = 20)
plt.plot(df.index, df['petal.length'], markevery = 1, marker = 'd' )
plt.grid(True, color = 'k', linestyle = ':')
#plt.style.use('classic')
for name, group in df.groupby('variety'):
  plt.plot(group.index,group['petal.length'], label = name, markevery = 1, marker = 'd')
plt.legend()
plt.show()

# %% [markdown]
# while ploting graph we have so many techniques to makes it look more informative and beautiful,
# by using  various colors, markers, grids, styles, legend, titiles, x and y labels, figure size etc,,.

# %% [markdown]
# Now let's try this in seaborn plot

# %%
sns.set(rc = {'figure.figsize': (7,7)})
fig = sns.lineplot(x = df.index, y = df['petal.length'], markevery = 1, marker = 'd', data = df, hue = 'variety')
fig.set(xlabel= 'Index')
# Out:
# [Text(0.5, 0, 'Index')]

# %%
sns.lineplot(x= df['sepal.length'] , y = df['sepal.width']); # continues data vs continues data

# %% [markdown]
# # Strip plot
# The strip plot is similar to a scatter plot. It is often used along with other kinds of plots for better analysis. It is used to visualize the distribution of data points of the variable.
# In strip plot the data points may overlap with the other data points
#
# for more deatail
# https://www.youtube.com/watch?v=zhUyC3tPVQQ&list=PLtPIclEQf-3cG31dxSMZ8KTcDG7zYng1j&index=8

# %%
sns.stripplot(y = df['sepal.width'])

# %% [markdown]
#  In the above plot, categories are not considered. Considering the categories helps in better visualization as seen in the below plot.

# %%
sns.stripplot(x = df['variety'], y = df['sepal.width'])

# %% [markdown]
# if we change the axis of variable it looks like this

# %%
sns.stripplot(x = df['sepal.width'], y = df['variety'])

# %% [markdown]
# # 4. Swarm plot
# The swarm-plot, similar to a strip-plot, provides a visualization technique for univariate data to view the spread of values in a continuous variable. The only difference between the strip-plot and the swarm-plot is that the swarm-plot spreads out the data points of the variable automatically to avoid overlap and hence provides a better visual overview of the data.
#
# This type of plot sometimes known as “beeswarm”.
#
# for more details
# https://www.youtube.com/watch?v=5e9NBhGBVwk&list=PLtPIclEQf-3cG31dxSMZ8KTcDG7zYng1j&index=7

# %%
sns.set_style('whitegrid')

# %%
sns.swarmplot(df['sepal.width']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.swarmplot(x = df['variety'], y = df['sepal.width']) # when we use a third variable we can use doge property

# %% [markdown]
# # Univariate summary plots
# These plots give a more concise description of the location, dispersion, and distribution of a variable than an enumerative plot. It is not feasible to retrieve every individual data value in a summary plot, but it helps in efficiently representing the whole data from which better conclusions can be made on the entire data set.

# %% [markdown]
# # 1. Histograms
# Histograms are similar to bar charts which display the counts or relative frequencies of values falling in different class intervals or ranges. A histogram displays the shape and spread of continuous sample data. It also helps us understand the skewness and kurtosis of the distribution of the data.
#
# if you are unfamiliar with skewness and kurtosis watch this video
# https://www.youtube.com/watch?v=MghAx7UaoUQ
#
# for more deatils
# https://www.youtube.com/watch?v=Bjz00ygERxY&list=PLtPIclEQf-3cG31dxSMZ8KTcDG7zYng1j&index=3

# %%
plt.hist(df['sepal.width']);

# %%
# in the previous ways to build a histogram we use distplot in seaborn, well all now is changed.
# seaborn 0.11.1 version comes with a new distributions Histplot, Distplot, ecdfplot, so now we check our version
sns.__version__
# Out:
# '0.11.2'

# %%
sns.histplot(df['sepal.width'])

# %%
sns.distplot(df['sepal.width'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.ecdfplot(df['sepal.length'])

# %% [markdown]
# 2.Density Plot :
#
# A density plot is a representation of the distribution of a numeric variable. It uses a kernel density estimate to show the probability density function of the variable.
#
# It is a smoothed version of the histogram and is used in the same concept
#
# we use the pandas df.plot() function (built over matplotlib) or the seaborn library’s sns.kdeplot() function to plot a density plot . Many features like shade, type of distribution, etc can be set using the parameters available in the functions. By default, the kernel used is Gaussian (this produces a Gaussian bell curve). Also, other graph smoothing techniques/filters are applicable.

# %%
plt.figure(figsize=(7,7))
df['petal.length'].plot(kind = 'density');

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.kdeplot(df['petal.length'],shade = True);

# %% [markdown]
# # 3. Rug plot
#
# A rug plot is a very simple, but also an ideal legitimate, way of representing a distribution. It consists of vertical lines at each data point. Here, the height is arbitrary. The density of the distribution can be known by how dense the tick-marks are.
#
# The connection between the rug plot and histogram is very direct: a histogram just creates bins along with the range of the data and then draws a bar with height equal to the number of ticks in each bin. In a rug plot, all of the data points are plotted on a single axis, one tick mark or line for each one.

# %%
fig, ax = plt.subplots()
sns.rugplot(df['sepal.length'])
ax.set_xlim(3,9)
plt.show()

# %% [markdown]
# # 4. Box plot
#
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.
#
# ![1_FPnhYs6cs3ipUKIZhl9caA.png](data:image/png;base64,...)

# %%
plt.boxplot(df['sepal.width']);

# %% [markdown]
# Plotting box plots of all variables in one frame :
#
# Since the box plot is for continuous variables, firstly create a data frame without the column ‘variety’. Then drop the column from the DataFrame using the drop( ) function and specify axis=1 to indicate it.

# %%
new_df = df.drop('variety',axis=1)

# %%
plt.figure(figsize=(7,7))
plt.boxplot(new_df.values,labels=['sepal lenght','sepal width','petal length','petal width']);

# %% [markdown]
# In matplotlib, we need to mention the labels separately to display it in the output. In seaborn it is different case

# %%
sns.boxplot(df['sepal.width']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set(rc = {'figure.figsize':(9,9)})
sns.boxplot(x = 'variable',y='value', data =pd.melt(new_df));

# %% [markdown]
# 5. Violin plot
#
# The Violin plot is very much similar to a box plot, with the addition of a rotated kernel density plot on each side. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.

# %%
new_df = df.drop('variety',axis=1)

# %%
plt.figure(figsize = (7,7))
plt.violinplot(new_df.values,showmedians = True);

# %%
sns.set(rc = {'figure.figsize': (5,5)})
sns.violinplot(df['sepal.width'],orient = 'vertical');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.set(rc = {'figure.figsize': (9,9)} )
sns.violinplot(x = df['variety'], y = df['sepal.width'], data = df);

# %% [markdown]
# # Visulization of Catergorical variables :

# %% [markdown]
# 1. Bar chart :
#
#    The bar plot is a univariate data visualization plot on a two-dimensional axis. One axis is the category axis indicating the category, while the second axis is the value axis that shows the numeric value of that category, indicated by the length of the bar.

# %%
plt.figure(figsize = (7,7))
df['variety'].value_counts().plot.bar()

# %%
sns.barplot(x ='variety', y ='sepal.width', data = df)

# %% [markdown]
# 2. Pie chart :
#
# A pie chart is the most common way used to visualize the numerical proportion occupied by each of the categories.

# %%
plt.pie(df['variety'].value_counts(),
         labels = ['Setosa', 'Versicolor','Virginica']);
